# %% [markdown]
# # The purpose of this notebook is to introduce someone and his/her holiday preferences with a picture and a link to a YT video of their holiday preference.

# %%
name = input("Name?: ")

# %% [markdown]
# ![275444122_643014350092246_2511245142298437435_n.jpg](attachment:275444122_643014350092246_2511245142298437435_n.jpg) Photo of person

# %% [markdown]
# ![273596510_539974163807305_8053527986923385407_n.jpg](attachment:273596510_539974163807305_8053527986923385407_n.jpg) Photo of destination - Turkey

# %% [markdown]
# Top three things Matthias likes to do at this destination:
# * Run at 7am
# * Adventure & Explore the Wild
# * Forage for local fruits

# %% [markdown]
# https://www.youtube.com/watch?v=vJUT1zFYYYE - #Youtube of place
