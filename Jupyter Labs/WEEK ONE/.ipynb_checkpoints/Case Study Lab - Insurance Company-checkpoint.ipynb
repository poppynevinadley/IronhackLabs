# %% [markdown]
# # Data Analysis How-To Report

# %% [markdown]
# An overly lengthy yet detailed road to basic data analysis.
# To be edited before adding to portfolio.
# ### Aggregation into one Data Frame

# %%
import numpy as np                                      
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import statsmodels.api as sm
from scipy.stats import boxcox
pd.options.display.max_rows = 100

# %%
file1 = pd.read_csv('Data/file1.csv')
file2 = pd.read_csv('Data/file2.csv')
file3 = pd.read_csv('Data/file3.csv')

# %%
file1.head()
# Out:
#   Customer          ST GENDER             Education Customer Lifetime Value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     Income  Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    Vehicle Class  Total Claim Amount
# 0  Four-Door Car            2.704934
# 1  Four-Door Car         1131.464935
# 2   Two-Door Car          566.472247
# 3            SUV          529.881344
# 4  Four-Door Car           17.269323

# %% [markdown]
# ### Unification of Columns

# %%
list(file1.columns)           #check all columns so can see if different to other files and if need to be changed & unified.
# Out:
# ['Customer',
#  'ST',
#  'GENDER',
#  'Education',
#  'Customer Lifetime Value',
#  'Income',
#  'Monthly Premium Auto',
#  'Number of Open Complaints',
#  'Policy Type',
#  'Vehicle Class',
#  'Total Claim Amount']

# %%
list(file2.columns)
# Out:
# ['Customer',
#  'ST',
#  'GENDER',
#  'Education',
#  'Customer Lifetime Value',
#  'Income',
#  'Monthly Premium Auto',
#  'Number of Open Complaints',
#  'Total Claim Amount',
#  'Policy Type',
#  'Vehicle Class']

# %%
list(file3.columns)
# Out:
# ['Customer',
#  'State',
#  'Customer Lifetime Value',
#  'Education',
#  'Gender',
#  'Income',
#  'Monthly Premium Auto',
#  'Number of Open Complaints',
#  'Policy Type',
#  'Total Claim Amount',
#  'Vehicle Class']

# %% [markdown]
# #### Renaming of Columns

# %%
file1.rename(columns={'ST':'State'}, inplace=True)              #change the differences found to unify columns
file2.rename(columns={'ST':'State'}, inplace=True)
list(file1.columns)                                             #check if worked
# Out:
# ['Customer',
#  'State',
#  'GENDER',
#  'Education',
#  'Customer Lifetime Value',
#  'Income',
#  'Monthly Premium Auto',
#  'Number of Open Complaints',
#  'Policy Type',
#  'Vehicle Class',
#  'Total Claim Amount']

# %%
file2.rename(columns={'GENDER':'Gender'}, inplace=True)
file3.rename(columns={'GENDER':'Gender'}, inplace=True)
list(file2.columns)
# Out:
# ['Customer',
#  'State',
#  'Gender',
#  'Education',
#  'Customer Lifetime Value',
#  'Income',
#  'Monthly Premium Auto',
#  'Number of Open Complaints',
#  'Total Claim Amount',
#  'Policy Type',
#  'Vehicle Class']

# %% [markdown]
# #### Re-ordering of columns

# %%
file2 = file2 [['Customer',                                       #reorder as seen above that they are not in the same order
 'State',
 'Gender',
 'Education',
 'Customer Lifetime Value',
 'Income',
 'Monthly Premium Auto',
 'Number of Open Complaints',
 'Policy Type',
 'Vehicle Class', 'Total Claim Amount']]
list(file2.columns)
# Out:
# ['Customer',
#  'State',
#  'Gender',
#  'Education',
#  'Customer Lifetime Value',
#  'Income',
#  'Monthly Premium Auto',
#  'Number of Open Complaints',
#  'Policy Type',
#  'Vehicle Class',
#  'Total Claim Amount']

# %%
file3 = file3 [['Customer',
 'State',
 'Gender',
 'Education',
 'Customer Lifetime Value',
 'Income',
 'Monthly Premium Auto',
 'Number of Open Complaints',
 'Policy Type',
 'Vehicle Class', 'Total Claim Amount']]
list(file3.columns)
# Out:
# ['Customer',
#  'State',
#  'Gender',
#  'Education',
#  'Customer Lifetime Value',
#  'Income',
#  'Monthly Premium Auto',
#  'Number of Open Complaints',
#  'Policy Type',
#  'Vehicle Class',
#  'Total Claim Amount']

# %% [markdown]
# #### Concatenating Files

# %%
df = pd.concat([file1,file2,file3], axis=0)
df
# Out:
#      Customer       State GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California    NaN              Bachelor
# 7066  PK87824  California    NaN               College
# 7067  TD14365  California    NaN              Bachelor
# 7068  UP19263  California    NaN               College
# 7069  Y167826  California    NaN               College
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# 3                 764586.18%      0.0                 106.0
# 4                 536307.65%  36357.0                  68.0
# ...                      ...      ...                   ...
# 7065             23405.98798  71941.0                  73.0
# 7066             3096.511217  21604.0                  79.0
# 7067             8163.890428      0.0                  85.0
# 7068             7524.442436  21941.0                  96.0
# 7069             2611.836866      0.0                  77.0
#
#      Number of Open Complaints     Policy Type  Vehicle Class  \
# 0                       1/0/00   Personal Auto  Four-Door Car
# 1                       1/0/00   Personal Auto  Four-Door Car
# 2                       1/0/00   Personal Auto   Two-Door Car
# 3                       1/0/00  Corporate Auto            SUV
# 4                       1/0/00   Personal Auto  Four-Door Car
# ...                        ...             ...            ...
# 7065                         0   Personal Auto  Four-Door Car
# 7066                         0  Corporate Auto  Four-Door Car
# 7067                         3  Corporate Auto  Four-Door Car
# 7068                         0   Personal Auto  Four-Door Car
# 7069                         0  Corporate Auto   Two-Door Car
#
#       Total Claim Amount Gender
# 0               2.704934    NaN
# 1            1131.464935    NaN
# 2             566.472247    NaN
# 3             529.881344    NaN
# 4              17.269323    NaN
# ...                  ...    ...
# 7065          198.234764      M
# 7066          379.200000      F
# 7067          790.784983      M
# 7068          691.200000      M
# 7069          369.600000      M
#
# [12074 rows x 12 columns]

# %%
df = df.reset_index(drop=True)                                             #resetting index as needed
df
# Out:
#       Customer       State GENDER             Education  \
# 0      RB50392  Washington    NaN                Master
# 1      QZ44356     Arizona      F              Bachelor
# 2      AI49188      Nevada      F              Bachelor
# 3      WW63253  California      M              Bachelor
# 4      GA49547  Washington      M  High School or Below
# ...        ...         ...    ...                   ...
# 12069  LA72316  California    NaN              Bachelor
# 12070  PK87824  California    NaN               College
# 12071  TD14365  California    NaN              Bachelor
# 12072  UP19263  California    NaN               College
# 12073  Y167826  California    NaN               College
#
#       Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                         NaN      0.0                1000.0
# 1                  697953.59%      0.0                  94.0
# 2                 1288743.17%  48767.0                 108.0
# 3                  764586.18%      0.0                 106.0
# 4                  536307.65%  36357.0                  68.0
# ...                       ...      ...                   ...
# 12069             23405.98798  71941.0                  73.0
# 12070             3096.511217  21604.0                  79.0
# 12071             8163.890428      0.0                  85.0
# 12072             7524.442436  21941.0                  96.0
# 12073             2611.836866      0.0                  77.0
#
#       Number of Open Complaints     Policy Type  Vehicle Class  \
# 0                        1/0/00   Personal Auto  Four-Door Car
# 1                        1/0/00   Personal Auto  Four-Door Car
# 2                        1/0/00   Personal Auto   Two-Door Car
# 3                        1/0/00  Corporate Auto            SUV
# 4                        1/0/00   Personal Auto  Four-Door Car
# ...                         ...             ...            ...
# 12069                         0   Personal Auto  Four-Door Car
# 12070                         0  Corporate Auto  Four-Door Car
# 12071                         3  Corporate Auto  Four-Door Car
# 12072                         0   Personal Auto  Four-Door Car
# 12073                         0  Corporate Auto   Two-Door Car
#
#        Total Claim Amount Gender
# 0                2.704934    NaN
# 1             1131.464935    NaN
# 2              566.472247    NaN
# 3              529.881344    NaN
# 4               17.269323    NaN
# ...                   ...    ...
# 12069          198.234764      M
# 12070          379.200000      F
# 12071          790.784983      M
# 12072          691.200000      M
# 12073          369.600000      M
#
# [12074 rows x 12 columns]

# %% [markdown]
# #### Standardizing header names

# %%
def lower_case_column_names(df): 
    df.columns=[i.lower() for i in df.columns]                    #in list comprehension form as takes less processing power
    return df

# %%
df=lower_case_column_names(df) 
list(df.columns)
# Out:
# ['customer',
#  'state',
#  'gender',
#  'education',
#  'customer lifetime value',
#  'income',
#  'monthly premium auto',
#  'number of open complaints',
#  'policy type',
#  'vehicle class',
#  'total claim amount',
#  'gender']

# %% [markdown]
# #### Removing Duplicates

# %%
df = df.loc[:,~df.columns.duplicated()].copy() 
df
# Out:
#       customer       state gender             education  \
# 0      RB50392  Washington    NaN                Master
# 1      QZ44356     Arizona      F              Bachelor
# 2      AI49188      Nevada      F              Bachelor
# 3      WW63253  California      M              Bachelor
# 4      GA49547  Washington      M  High School or Below
# ...        ...         ...    ...                   ...
# 12069  LA72316  California    NaN              Bachelor
# 12070  PK87824  California    NaN               College
# 12071  TD14365  California    NaN              Bachelor
# 12072  UP19263  California    NaN               College
# 12073  Y167826  California    NaN               College
#
#       customer lifetime value   income  monthly premium auto  \
# 0                         NaN      0.0                1000.0
# 1                  697953.59%      0.0                  94.0
# 2                 1288743.17%  48767.0                 108.0
# 3                  764586.18%      0.0                 106.0
# 4                  536307.65%  36357.0                  68.0
# ...                       ...      ...                   ...
# 12069             23405.98798  71941.0                  73.0
# 12070             3096.511217  21604.0                  79.0
# 12071             8163.890428      0.0                  85.0
# 12072             7524.442436  21941.0                  96.0
# 12073             2611.836866      0.0                  77.0
#
#       number of open complaints     policy type  vehicle class  \
# 0                        1/0/00   Personal Auto  Four-Door Car
# 1                        1/0/00   Personal Auto  Four-Door Car
# 2                        1/0/00   Personal Auto   Two-Door Car
# 3                        1/0/00  Corporate Auto            SUV
# 4                        1/0/00   Personal Auto  Four-Door Car
# ...                         ...             ...            ...
# 12069                         0   Personal Auto  Four-Door Car
# 12070                         0  Corporate Auto  Four-Door Car
# 12071                         3  Corporate Auto  Four-Door Car
# 12072                         0   Personal Auto  Four-Door Car
# 12073                         0  Corporate Auto   Two-Door Car
#
#        total claim amount
# 0                2.704934
# 1             1131.464935
# 2              566.472247
# 3              529.881344
# 4               17.269323
# ...                   ...
# 12069          198.234764
# 12070          379.200000
# 12071          790.784983
# 12072          691.200000
# 12073          369.600000
#
# [12074 rows x 11 columns]

# %% [markdown]
# ##### Deleting and rearranging columns

# %%
def drop_columns(df):
    df.drop(columns=["customer"], inplace=True) 
    return df
drop_columns(df)
# Out:
#             state gender             education customer lifetime value  \
# 0      Washington    NaN                Master                     NaN
# 1         Arizona      F              Bachelor              697953.59%
# 2          Nevada      F              Bachelor             1288743.17%
# 3      California      M              Bachelor              764586.18%
# 4      Washington      M  High School or Below              536307.65%
# ...           ...    ...                   ...                     ...
# 12069  California    NaN              Bachelor             23405.98798
# 12070  California    NaN               College             3096.511217
# 12071  California    NaN              Bachelor             8163.890428
# 12072  California    NaN               College             7524.442436
# 12073  California    NaN               College             2611.836866
#
#         income  monthly premium auto number of open complaints  \
# 0          0.0                1000.0                    1/0/00
# 1          0.0                  94.0                    1/0/00
# 2      48767.0                 108.0                    1/0/00
# 3          0.0                 106.0                    1/0/00
# 4      36357.0                  68.0                    1/0/00
# ...        ...                   ...                       ...
# 12069  71941.0                  73.0                         0
# 12070  21604.0                  79.0                         0
# 12071      0.0                  85.0                         3
# 12072  21941.0                  96.0                         0
# 12073      0.0                  77.0                         0
#
#           policy type  vehicle class  total claim amount
# 0       Personal Auto  Four-Door Car            2.704934
# 1       Personal Auto  Four-Door Car         1131.464935
# 2       Personal Auto   Two-Door Car          566.472247
# 3      Corporate Auto            SUV          529.881344
# 4       Personal Auto  Four-Door Car           17.269323
# ...               ...            ...                 ...
# 12069   Personal Auto  Four-Door Car          198.234764
# 12070  Corporate Auto  Four-Door Car          379.200000
# 12071  Corporate Auto  Four-Door Car          790.784983
# 12072   Personal Auto  Four-Door Car          691.200000
# 12073  Corporate Auto   Two-Door Car          369.600000
#
# [12074 rows x 10 columns]

# %% [markdown]
# #### Data Types
# Hint: remove the percentage from the customer lifetime value and truncate it to an integer value.
# Clean the number of open complaints and extract the middle number which is changing between records. Pay attention that the number of open complaints is a categorical feature.

# %%
df.info()                                                                                      #to check for data types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12074 entries, 0 to 12073
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   state                      9137 non-null   object
#  1   gender                     954 non-null    object
#  2   education                  9137 non-null   object
#  3   customer lifetime value    9130 non-null   object
#  4   income                     9137 non-null   float64
#  5   monthly premium auto       9137 non-null   float64
#  6   number of open complaints  9137 non-null   object
#  7   policy type                9137 non-null   object
#  8   vehicle class              9137 non-null   object
#  9   total claim amount         9137 non-null   float64
# dtypes: float64(3), object(7)
# memory usage: 943.4+ KB

# %% [markdown]
# #### Changing to String first

# %%
df['customer lifetime value'] = df['customer lifetime value'].astype('string')  #as both were objects & should be integers

df['number of open complaints'] = df['number of open complaints'].astype('string')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12074 entries, 0 to 12073
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   state                      9137 non-null   object
#  1   gender                     954 non-null    object
#  2   education                  9137 non-null   object
#  3   customer lifetime value    9130 non-null   string
#  4   income                     9137 non-null   float64
#  5   monthly premium auto       9137 non-null   float64
#  6   number of open complaints  9137 non-null   string
#  7   policy type                9137 non-null   object
#  8   vehicle class              9137 non-null   object
#  9   total claim amount         9137 non-null   float64
# dtypes: float64(3), object(5), string(2)
# memory usage: 943.4+ KB

# %% [markdown]
# #### Removing '%'s

# %%
df['customer lifetime value'] = df['customer lifetime value'].str.replace('%','')  #checked that doesn't add more NaN values

df['number of open complaints'] = df['number of open complaints'].str.replace('%','')
df
# Out:
#             state gender             education customer lifetime value  \
# 0      Washington    NaN                Master                    <NA>
# 1         Arizona      F              Bachelor               697953.59
# 2          Nevada      F              Bachelor              1288743.17
# 3      California      M              Bachelor               764586.18
# 4      Washington      M  High School or Below               536307.65
# ...           ...    ...                   ...                     ...
# 12069  California    NaN              Bachelor             23405.98798
# 12070  California    NaN               College             3096.511217
# 12071  California    NaN              Bachelor             8163.890428
# 12072  California    NaN               College             7524.442436
# 12073  California    NaN               College             2611.836866
#
#         income  monthly premium auto number of open complaints  \
# 0          0.0                1000.0                    1/0/00
# 1          0.0                  94.0                    1/0/00
# 2      48767.0                 108.0                    1/0/00
# 3          0.0                 106.0                    1/0/00
# 4      36357.0                  68.0                    1/0/00
# ...        ...                   ...                       ...
# 12069  71941.0                  73.0                         0
# 12070  21604.0                  79.0                         0
# 12071      0.0                  85.0                         3
# 12072  21941.0                  96.0                         0
# 12073      0.0                  77.0                         0
#
#           policy type  vehicle class  total claim amount
# 0       Personal Auto  Four-Door Car            2.704934
# 1       Personal Auto  Four-Door Car         1131.464935
# 2       Personal Auto   Two-Door Car          566.472247
# 3      Corporate Auto            SUV          529.881344
# 4       Personal Auto  Four-Door Car           17.269323
# ...               ...            ...                 ...
# 12069   Personal Auto  Four-Door Car          198.234764
# 12070  Corporate Auto  Four-Door Car          379.200000
# 12071  Corporate Auto  Four-Door Car          790.784983
# 12072   Personal Auto  Four-Door Car          691.200000
# 12073  Corporate Auto   Two-Door Car          369.600000
#
# [12074 rows x 10 columns]

# %% [markdown]
# #### Clean & Extract Middle Number
#
# Before changing to Float to Int, removing //.
# How else to clean the number of open complaints?
# Pay attention that the number of open complaints is a categorical feature.
#
# ##### Options to explore:
#
# #a)
# import re
#
# for in in df['Number of complaints']:
#     if type (i) == str:
#         x = re.search(r'/(\d+)/', i')
#         df['Number of open complaints'] = x.group(1)
#     else:
#         df['Number of open complaints'] = x
#
# #b)
# apply.function
#
# #c)
# df = df['Number of complaints'].apply(lamda x: str(x).split('/')[0].split('/')[1]                     #regex similar to split

# %%
df['number of open complaints'] = df['number of open complaints'].astype(str).str.replace('(.*)/0/(.*)','0', regex=True)
df['number of open complaints'] = df['number of open complaints'].astype(str).str.replace('(.*)/2/(.*)','2', regex=True)
df['number of open complaints'] = df['number of open complaints'].astype(str).str.replace('(.*)/1/(.*)','1', regex=True)
df['number of open complaints'] = df['number of open complaints'].astype(str).str.replace('(.*)/3/(.*)','3', regex=True)
df['number of open complaints'] = df['number of open complaints'].astype(str).str.replace('(.*)/5/(.*)','5', regex=True)

df
# Out:
#             state gender             education customer lifetime value  \
# 0      Washington    NaN                Master                    <NA>
# 1         Arizona      F              Bachelor               697953.59
# 2          Nevada      F              Bachelor              1288743.17
# 3      California      M              Bachelor               764586.18
# 4      Washington      M  High School or Below               536307.65
# ...           ...    ...                   ...                     ...
# 12069  California    NaN              Bachelor             23405.98798
# 12070  California    NaN               College             3096.511217
# 12071  California    NaN              Bachelor             8163.890428
# 12072  California    NaN               College             7524.442436
# 12073  California    NaN               College             2611.836866
#
#         income  monthly premium auto number of open complaints  \
# 0          0.0                1000.0                         0
# 1          0.0                  94.0                         0
# 2      48767.0                 108.0                         0
# 3          0.0                 106.0                         0
# 4      36357.0                  68.0                         0
# ...        ...                   ...                       ...
# 12069  71941.0                  73.0                         0
# 12070  21604.0                  79.0                         0
# 12071      0.0                  85.0                         3
# 12072  21941.0                  96.0                         0
# 12073      0.0                  77.0                         0
#
#           policy type  vehicle class  total claim amount
# 0       Personal Auto  Four-Door Car            2.704934
# 1       Personal Auto  Four-Door Car         1131.464935
# 2       Personal Auto   Two-Door Car          566.472247
# 3      Corporate Auto            SUV          529.881344
# 4       Personal Auto  Four-Door Car           17.269323
# ...               ...            ...                 ...
# 12069   Personal Auto  Four-Door Car          198.234764
# 12070  Corporate Auto  Four-Door Car          379.200000
# 12071  Corporate Auto  Four-Door Car          790.784983
# 12072   Personal Auto  Four-Door Car          691.200000
# 12073  Corporate Auto   Two-Door Car          369.600000
#
# [12074 rows x 10 columns]

# %% [markdown]
# #### ONLY THING LEFT TO DO FOR LAB 1             --------------------------------------------------------          Changing to Float then to Integer

# %%
df['customer lifetime value'] =  pd.to_numeric(df['customer lifetime value'], errors='coerce') #changes it to float
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12074 entries, 0 to 12073
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   state                      9137 non-null   object
#  1   gender                     954 non-null    object
#  2   education                  9137 non-null   object
#  3   customer lifetime value    9130 non-null   float64
#  4   income                     9137 non-null   float64
#  5   monthly premium auto       9137 non-null   float64
#  6   number of open complaints  12074 non-null  object
#  7   policy type                9137 non-null   object
#  8   vehicle class              9137 non-null   object
#  9   total claim amount         9137 non-null   float64
# dtypes: float64(4), object(6)
# memory usage: 943.4+ KB

# %%
df['customer lifetime value'] =  df['customer lifetime value'].truncate
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12074 entries, 0 to 12073
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   state                      9137 non-null   object
#  1   gender                     954 non-null    object
#  2   education                  9137 non-null   object
#  3   customer lifetime value    12074 non-null  object
#  4   income                     9137 non-null   float64
#  5   monthly premium auto       9137 non-null   float64
#  6   number of open complaints  12074 non-null  object
#  7   policy type                9137 non-null   object
#  8   vehicle class              9137 non-null   object
#  9   total claim amount         9137 non-null   float64
# dtypes: float64(3), object(7)
# memory usage: 943.4+ KB

# %%
#change nan of mean of columns 
df['customer lifetime value'] = df['customer lifetime value'].fillna(df['customer lifetime value'].mean())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18272\2073998289.py in <module>
#       1 #change nan of mean of columns
# ----> 2 df['customer lifetime value'] = df['customer lifetime value'].fillna(df['customer lifetime value'].mean())
#
# ~\Documents\Ananconda\lib\site-packages\pandas\core\generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11122             **kwargs,
#   11123         ):
# > 11124             return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11125
#   11126         setattr(cls, "mean", mean)
#
# ~\Documents\Ananconda\lib\site-packages\pandas\core\generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10692         **kwargs,
#   10693     ) -> Series | float:
# > 10694         return self._stat_function(
#   10695             "mean", nanops.nanmean, axis, skipna, level, numeric_only, **kwargs
#   10696         )
#
# ~\Documents\Ananconda\lib\site-packages\pandas\core\generic.py in _stat_function(self, name, func, axis, skipna, level, numeric_only, **kwargs)
#   10644                 name, axis=axis, level=level, skipna=skipna, numeric_only=numeric_only
#   10645             )
# > 10646         return self._reduce(
#   10647             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   10648         )
#
# ~\Documents\Ananconda\lib\site-packages\pandas\core\series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4469                 )
#    4470             with np.errstate(all="ignore"):
# -> 4471                 return op(delegate, skipna=skipna, **kwds)
#    4472
#    4473     def _reindex_indexer(
#
# ~\Documents\Ananconda\lib\site-packages\pandas\core\nanops.py in _f(*args, **kwargs)
#      91             try:
#      92                 with np.errstate(invalid="ignore"):
# ---> 93                     return f(*args, **kwargs)
#      94             except ValueError as e:
#      95                 # we want to transform an object array
#
# ~\Documents\Ananconda\lib\site-packages\pandas\core\nanops.py in f(values, axis, skipna, **kwds)
#     153                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     154             else:
# --> 155                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     156
#     157             return result
#
# ~\Documents\Ananconda\lib\site-packages\pandas\core\nanops.py in new_func(values, axis, skipna, mask, **kwargs)
#     408             mask = isna(values)
#     409
# --> 410         result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     411
#     412         if datetimelike:
#
# ~\Documents\Ananconda\lib\site-packages\pandas\core\nanops.py in nanmean(values, axis, skipna, mask)
#     696
#     697     count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 698     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     699
#     700     if axis is not None and getattr(the_sum, "ndim", False):
#
# ~\Documents\Ananconda\lib\site-packages\numpy\core\_methods.py in _sum(a, axis, dtype, out, keepdims, initial, where)
#      46 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      47          initial=_NoValue, where=True):
# ---> 48     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#      49
#      50 def _prod(a, axis=None, dtype=None, out=None, keepdims=False,
#
# TypeError: unsupported operand type(s) for +: 'method' and 'method'

# %%
#then put it into an int and dropna first
#df = df.dropna() get rid of this

# %%
df['customer lifetime value'] = df['customer lifetime value'].astype(int) #change to integers
df.select_dtypes(int)

# %%
df['number of open complaints'] = df['number of open complaints'].astype(int) 
df.select_dtypes(int)

# %%
#then do same with the complaints one!

# %% [markdown]
# #### FILTERING & CORRECTING

# %%
df.gender.unique()

# %%
def clean_gender(x):
    if x in ['M','male']:
        return 'Male'
    elif x in ['F', 'female',"Femal"]:
        return 'Female'
    elif np.nan:  pass
    else:
        return 'U' #if x if it contains what's in [], then return.

# %%
df['gender'] = list(map(clean_gender, df['gender'])) 
df

# %%
df.state.unique()

# %%
def clean_state(x):
    if x in ['AZ','Arizona']:
        return 'Arizona'
    elif x in ['WA', 'Washington']:
        return 'Washington'
    elif x in ['Cali', 'California']:
        return 'California'
    elif x in ['Nevada']:
        return 'Nevada'
    elif x in ['Oregon']:
        return 'Oregon'
    elif np.nan:  pass
    else:
        return 'U' #if x if it contains what's in [], then return.

# %%
df['state'] = list(map(clean_state, df['state'])) 
df

# %% [markdown]
# # Second part

# %% [markdown]
# ### Replacement of Null Values  ---------------------------------------------------------- NOT READY

# %% [markdown]
# Replacing null values – Replace missing values with means of the column (for numerical columns). Pay attention that the Income feature for instance has 0s which is equivalent to null values. (We assume here that there is no such income with 0 as it refers to missing values).
# Hint: numpy.nan is considered of float64 data type.
#
# Replacing null values for categorical variables
# General Approaches:
# Ignore observation
# Replace by most frequent value
# Replace using an algorithm like KNN using the neighbours.
# Predict the observation using a multiclass predictor
# Treat missing data as just another category

# %% [markdown]
# nulls_df = pd.DataFrame(round(hk_df.isna().sum()/len(hk_df),4)*100) #name of column and % of null values inside and you
# #decide whether to drop it threshold if problem has around 20-30% then drop the column unless specified otherwise.
# nulls_df = nulls_df.reset_index()
# nulls_df.columns = ['header_name', 'percent_nulls']
# nulls_df

# %%
#customer lifetime value = np.mean(df['customer lifetime value'])

back into a float first 

df['customer lifetime value'] = df['customer lifetime value'].fillna(df['customer lifetime value'].mean())

back into an integer
 
filled na income then replace 0
income = income].replace([0]), df[income].mean()

#whether or not to replace 0s with nan- income one it does to
#replace by the mean or the median, then get the mean etc but i.e number of open complaints can accept 0's whereas if 
#replace with mean then get some incorrect.

# %%
#change the NA to the mean of the colum
df['customer lifetime value'] = df['customer lifetime value'].fillna(df['customer lifetime value'].mean())
#convert to integer
df['customer lifetime value'] = df['customer lifetime value'].astype(int)
df['income'] = df['income'].fillna(df['income'].mean())
df['income'] = df['income'].replace([0], df['income'].mean())
df['number of open complaints'] = df['number of open complaints'].fillna(df['number of open complaints'].mean())
df['number of open complaints'] = df['number of open complaints'].replace([0], df['number of open complaints'].mean())

# %%
df.info()                                     #then see how to see if they are non-null or not and how
                                    #df.isna().value.counts - do it per column then to find out if need to drop the columns

# %%
df

# %% [markdown]
# ## Bucketing the data
#
# As: Arizona + Nevada = Central, California = West Region, Washington = East, Oregon = North West.

# %%
df.state.unique() #up to you to have new column called region, extra column in data, or rename 'region'

# %%
def state_zoning(x):
    if x in ['Arizona', 'Nevada']:
        return 'Central'
    elif x in ['California']:
        return 'West Region'
    elif x in ['Washington']:
        return 'East Region'
    elif x in ['Oregon']:
        return 'North West'
    elif np.nan:  pass
    else:
        return 'U'
    
df['state'] = list(map(state_zoning, df['state'])) 
df

# %% [markdown]
# #### Another option to explore:
#
# df['State Zones'] = pd.cut(df['State'], bins=['Arizona', 'Nevada', 'California', 'Washington', 'Oregon', 'AZ',
#        'WA', 'Cali'], labels=['Central', 'West Region', 'Young Adult', 'Adult', 'Elder'])
# print(df)
# print(df[['Customer ID', 'Gender', 'Age', 'age_category']])

# %%
#RE-NAME COLUMN TO 'region'

# %% [markdown]
# #### Rounding decimals

# %%
df['total claim amount'] = df['total claim amount'].round(decimals = 1)
df['income'] = df['income'].round(decimals = 0)
df

# %% [markdown]
# #### Questions left
#
# #fillna(0) - fill nons with 0 as 0 complaints - an assumption
#
# #is it better to call it something else than df
#
# #do i need to pull the changes from github

# %% [markdown]
# #### Optional

# %% [markdown]
# In the column `Vehicle Class`, nerge the two categories `Luxury SUV` and `Luxury Car` into one category
# named `Luxury Vehicle`.

# %%
ca_df['luxury vehicle'] = ca_df['vehicle class'].replace('California', "West Region") 
# DO for luxury cars

# %% [markdown]
# Removing outliers using 1.5*IQR technique for all numerical columns.

# %%
#So 1.5 outside the IQR technique for all numerical columns. good measure of what we mean by an outlier as that 
#captures most of it so anything outside of it says a lot. Hint: built in functions quantiles

def remove_outlier(column, df):
percentile = df[columnname].quantile(0.25) #make lower and higher so don't take off so much data

iqr = percentile 75 + per 25
upper limit = percentile 75 + 1.5*iqr
lower limit = 

df.replace(to_replace= df[column][df[column] > upper limit], value = 'outlier', implace = True)
same again < lower limit
numberofvaluesdropped = f* you replaced (df[column][df[column]] > upper limit].shape[0] + df[column][dfcolumn]
return numberofvaluesdropped #add in underscore

removeoutlier('income', df)
removeoutlier('cusotmer lifetime', df)
removeoutlier('monthly premiium ', df)

print(outliers.head)

# %% [markdown]
# # THIRD PART

# %%
file3 = pd.read_csv('./Data/Data_Marketing_Customer_Analysis_Round3.csv')
file3.head()

# %% [markdown]
# ### Into Dataframes

# %%
numerical = file3.select_dtypes(include=[np.number])
numerical.head()

# %%
numerical.info() #bar charts - between numerical and categorical or categorical

# %%
categorical = file3.select_dtypes(include=[object])
categorical.head()
categorical.info()

# %%
categorical.columns.drop("effective_to_date")

# %% [markdown]
# ### Normality of the Numerical Variables

# %%
fig, ax = plt.subplots(4, 2, figsize= (20,15))
sns.histplot(data=numerical, x='income', ax=ax[0,0])
sns.histplot(data=numerical, x='customer_lifetime_value', ax=ax[0,1])
sns.histplot(data=numerical, x='monthly_premium_auto', ax=ax[1,0])
sns.histplot(data=numerical, x='months_since_last_claim', ax=ax[1,1])
sns.histplot(data=numerical, x='months_since_policy_inception', ax=ax[2,0])
sns.histplot(data=numerical, x='number_of_open_complaints', ax=ax[2,1])
sns.histplot(data=numerical, x='number_of_policies', ax=ax[3,0])
sns.histplot(data=numerical, x='total_claim_amount', ax=ax[3,1])

# %%
numerical.hist(figsize=(10,15))

# %% [markdown]
# Do the distributions for different numerical variables look like a normal distribution?
#
# = Only 'months_since_policy_inception' and 'income' have a slightly more normal distribution.

# %% [markdown]
# ### Multicollinearity between the Input Features

# %%
num_cols = numerical.columns.drop("total_claim_amount")
sns.pairplot(numerical[num_cols])

# %% [markdown]
# ### Correlation Heatmap

# %%
corr = numerical.corr() # calculate the correlation matrix

sns.heatmap(corr, xticklabels=corr.columns,yticklabels=corr.columns, annot=True)    # plot the heatmap

# %% [markdown]
# ## Optional
#
# Drop one of the two features that show a high correlation between them (greater than 0.9).
# If there is no pair of features that have a high correlation, then do not drop any features.
#
# Yet there are none.

# %% [markdown]
# ## Fourth Part

# %% [markdown]
# (Optional) plot any interesting findings/insights(minimum three) that describe some interesting facts about your data
# set and its input variables as well as relationships with the target feature.
#
# Clean your notebook and make it a readable and presentable with a good documentation that summarizes the Data Cleaning,
# Exploration(including plots) Steps that you have performed

# %% [markdown]
# ### Plots

# %% [markdown]
# - Show a plot of the total number of responses.
# - Show a plot of the response by the sales channel.
# - Show a plot of the response by the total claim amount.
# - Show a plot of the response by income.
